# %% [markdown]
# ## Alzheimer

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
alz = pd.read_csv('./data/alzheimer/raw/alzheimers_disease_data.csv')
alz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
### Origen: https://www.kaggle.com/datasets/rabieelkharoua/alzheimers-disease-dataset
alz_num = alz.select_dtypes(include=['int','float'])
plt.figure(figsize=(15,8))
sns.heatmap(round(alz_num.corr(),2), vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.histplot(alz['Diagnosis']);

# %% [markdown]
# ## Dataset Kaggle

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
### Origen: https://www.kaggle.com/datasets/purumalgi/music-genre-classification?select=train.csv
df = pd.read_csv('data/raw/train.csv')
df.head()
# Out:
#              Artist Name                             Track Name  Popularity  \
# 0             Bruno Mars  That's What I Like (feat. Gucci Mane)        60.0
# 1                 Boston                           Hitch a Ride        54.0
# 2          The Raincoats                     No Side to Fall In        35.0
# 3                   Deno             Lingo (feat. J.I & Chunkz)        66.0
# 4  Red Hot Chili Peppers      Nobody Weird Like Me - Remastered        53.0
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.854   0.564   1.0    -4.964     1       0.0485      0.017100
# 1         0.382   0.814   3.0    -7.230     1       0.0406      0.001100
# 2         0.434   0.614   6.0    -8.334     1       0.0525      0.486000
# 3         0.853   0.597  10.0    -6.528     0       0.0555      0.021200
# 4         0.167   0.975   2.0    -4.279     1       0.2160      0.000169
#
# ...

# %%
df_num = df.select_dtypes(include=['int','float'])
sns.heatmap(df_num.corr().round(2), vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Trabajo con dataset Nsynth

# %%
import json
import pandas as pd
import seaborn as sns

# %%
# json.loads('C:\Users\raulg\Downloads\nsynth-test\examples.json')
data = pd.read_json("./data/raw/examples.json").T
data.head()
# Out:
#                                                         note_str sample_rate  \
# keyboard_acoustic_004-060-025      keyboard_acoustic_004-060-025       16000
# bass_synthetic_033-050-100            bass_synthetic_033-050-100       16000
# bass_synthetic_009-052-050            bass_synthetic_009-052-050       16000
# keyboard_electronic_003-064-127  keyboard_electronic_003-064-127       16000
# bass_synthetic_034-030-050            bass_synthetic_034-030-050       16000
#
#                                                       qualities_str  \
# keyboard_acoustic_004-060-025                        [dark, reverb]
# bass_synthetic_033-050-100                                   [dark]
# bass_synthetic_009-052-050       [bright, distortion, long_release]
# keyboard_electronic_003-064-127                                  []
# bass_synthetic_034-030-050               [distortion, tempo-synced]
#
#                                 instrument_source instrument_family_str  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12678 entries, keyboard_acoustic_004-060-025 to keyboard_acoustic_004-044-127
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   note_str               12678 non-null  object
#  1   sample_rate            12678 non-null  object
#  2   qualities_str          12678 non-null  object
#  3   instrument_source      12678 non-null  object
#  4   instrument_family_str  12678 non-null  object
#  5   instrument_family      12678 non-null  object
#  6   note                   12678 non-null  object
#  7   instrument_source_str  12678 non-null  object
#  8   qualities              12678 non-null  object
#  9   pitch                  12678 non-null  object
#  10  instrument_str         12678 non-null  object
#  11  instrument             12678 non-null  object
#  12  velocity               12678 non-null  object
# dtypes: object(13)
# memory usage: 1.9+ MB

# %%
data['sample_rate'] = data['sample_rate'].astype(float) 
data['instrument_source'] = data['instrument_source'].astype(float)
data['instrument_family'] = data['instrument_family'].astype(float)
data['note'] = data['note'].astype(float)
data['pitch'] = data['pitch'].astype(float)
data['velocity'] = data['velocity'].astype(float)

# %%
data_num = data.select_dtypes(include=['int','float'])
sns.heatmap(data_num.corr(), vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Conexión con API

# %%
import pycurl
import certifi
from io import BytesIO
from urllib.parse import urlencode

buffer = BytesIO()
c = pycurl.Curl()
c.setopt(c.URL, 'https://accounts.spotify.com/api/token')
post_data = {}
postfields = urlencode(post_data)
c.perform()
c.close()

body = buffer.getvalue()
# Body is a byte string.
# We have to know the encoding in order to print it to a text file
# such as standard output.
print(body.decode('iso-8859-1'))

# %%
### Para conseguir access token de Spotify API

import pycurl
from io import BytesIO
import json 

import re

# Crear un buffer para almacenar la respuesta
response_buffer = BytesIO()

# Configurar la solicitud de pycurl
c = pycurl.Curl()
c.setopt(c.URL, "https://accounts.spotify.com/api/token")
c.setopt(c.POST, 1)
c.setopt(c.HTTPHEADER, ["Content-Type: application/x-www-form-urlencoded"])
c.setopt(c.POSTFIELDS, "grant_type=client_credentials&client_id=546175eb5d9640bdbafd0bf2afa96e6d&client_secret=0271dada62dd4f15abe74f79ddefd62a")
c.setopt(c.WRITEDATA, response_buffer)

# Realizar la solicitud
c.perform()

# Obtener el código de respuesta HTTP (opcional)
http_code = c.getinfo(pycurl.RESPONSE_CODE)

# Finalizar la sesión de pycurl
c.close()

# Obtener el contenido de la respuesta
response_body = response_buffer.getvalue().decode('utf-8')

print(f"HTTP Code: {http_code}")
print("Response:", response_body)
# Out:
# HTTP Code: 200
# Response: {"access_token":"BQCoTI6Sspf5NSqx172m8QbjkSThpFKkPe8EFW459wGWrZ2E2mYzPWa2GYATBQ7SSMXJZPEfdTSNiYgJSoiS2WVa7SCwkHK8vvR4R1rh64lOjvs8Ess","token_type":"Bearer","expires_in":3600}

# %%
c = pycurl.Curl()
c.setopt(c.URL, "https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag")
c.setopt(c.HTTPHEADER, [
    "Authorization: Bearer BQB-6fXa_eFio_jIVvZSZ8QItkB-XtTPJHEsoRt_M98FTFUwgiOk7iR-GZNSgM7ICAphO6wC3qylf8j9dVJLxiB3FomlWJnl9-1wyAFSFD-nGLCsMgs"
])

# Especifica dónde escribir la respuesta
c.setopt(c.WRITEDATA, response_buffer)

# Realizar la solicitud
c.perform()

# Obtener el código de respuesta HTTP (opcional)
http_code = c.getinfo(pycurl.RESPONSE_CODE)

# Finalizar la sesión de pycurl
c.close()

# Obtener el contenido de la respuesta
response_body = response_buffer.getvalue().decode('utf-8')
# json_strings = re.findall(r'\{.*?\}(?=\{|\Z)', response_body)
# json_objects = response_body.split("}{")  # Dividir entre objetos

# Vuelve a agregar los corchetes a cada objeto y convierte a diccionario
# json_objects = [json.loads(f"{{{obj}}}") if i == 0 else json.loads(f"{{{obj}}}") for i, obj in enumerate(json_objects)]

print(f"HTTP Code: {http_code}")
print("Response:", response_body)
# print("Response as list of dictionaries:", json_objects)
response_body
# Out:
# HTTP Code: 200
# ...

# %%
### Guardamos el string de response_body a json
with open("./data/processed/output.txt", "a") as f:
  print(response_body, file=f)

# %%
response_body.as
# Out:
# str

# %% [markdown]
# ## Conoexión con requests

# %%
### Con requests
import hashlib
import requests
import datetime
import pandas as pd

access_token = 'BQB-6fXa_eFio_jIVvZSZ8QItkB-XtTPJHEsoRt_M98FTFUwgiOk7iR-GZNSgM7ICAphO6wC3qylf8j9dVJLxiB3FomlWJnl9-1wyAFSFD-nGLCsMgs'
client_id = '546175eb5d9640bdbafd0bf2afa96e6d'
client_secret = '0271dada62dd4f15abe74f79ddefd62a'
url = 'https://accounts.spotify.com/api/token'
red_uri = 'http://localhost:3000'
header = {"Content-Type": "application/x-www-form-urlencoded"}
params = {'grant_type':'client_credentials',
          'client_id':client_id,
          'client_secret':client_secret}

# %%
res = requests.get(url,params=params,headers=header)
print(res.status_code)
# res.json()
# Out:
# 405

# %% [markdown]
# ## Spotipy

# %% [markdown]
# ### Conexión original

# %%
### TODO: CUIDADO CON PUBLICAR EL CLIENT_SECRET!! Buscar cómo meter como variable de entorno
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope,
                                               client_id='546175eb5d9640bdbafd0bf2afa96e6d',
                                               client_secret='0271dada62dd4f15abe74f79ddefd62a',
                                               redirect_uri='http://localhost:3000'))

results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# 0 Yves Tumor  –  Echolalia
# 1 Blue Material  –  Blue Blood
# 2 The Weeknd  –  How Do I Make You Love Me?
# 3 Praga  –  Restaurantes Chinos
# 4 Yo Diablo  –  Balas
# 5 Warmduscher  –  The Sweet Smell of Florida
# 6 Oumou Sangaré  –  Mogoya
# 7 Yard Act  –  Dream Job
# 8 Automatic  –  New Beginning
# 9 The Lazy Eyes  –  Where's My Brain???
# 10 BODEGA  –  Territorial Call of the Female
# 11 Sorry  –  Right Round The Clock
# 12 Nadine Shah  –  Fool
# 13 Night Beats  –  New Day
# 14 The Sleepy Jackson  –  Good Dancers
# 15 Parquesvr  –  Barba Esconde Papada
# 16 The Gardener  –  Cuando coño se dice ole
# 17 Stereo MC's  –  Connected
# 18 Luna  –  23 Minutes in Brussels
# 19 Santero y Los Muchachos  –  Dragón

# %%
## Playlists:
### Rock 2024: https://open.spotify.com/playlist/37i9dQZF1DX2T25mA6YJhO
### Rock en español: https://open.spotify.com/playlist/37i9dQZF1DWUNNEvaozpW5
### Novedades rock: https://open.spotify.com/playlist/37i9dQZF1DX1MT1Ubz4wvO
### All new rock: https://open.spotify.com/playlist/37i9dQZF1DWZryfp6NSvtz
### Marrow: https://open.spotify.com/playlist/37i9dQZF1DXcF6B6QPhFDv
### Fresh finds rock: https://open.spotify.com/playlist/37i9dQZF1DX78toxP7mOaJ
### Hard rock: https://open.spotify.com/playlist/37i9dQZF1DX1X7WV84927n
### New Noise: https://open.spotify.com/playlist/37i9dQZF1DWT2jS7NwYPVI
### Volume: https://open.spotify.com/playlist/37i9dQZF1DWWJOmJ7nRx0C
### Rock Frequency: https://open.spotify.com/playlist/37i9dQZF1DX14rbJEM3cke
### Women of rock: https://open.spotify.com/playlist/37i9dQZF1DXd0ZFXhY0CRF
### Legends of rock: https://open.spotify.com/playlist/37i9dQZF1DX5a39zUmS7Hn
### Alt now: https://open.spotify.com/playlist/37i9dQZF1DWVqJMsgEN0F4
### The new alt: https://open.spotify.com/playlist/37i9dQZF1DX82GYcclJ3Ug

playlists=['spotify:playlist:37i9dQZF1DX2T25mA6YJhO','spotify:playlist:37i9dQZF1DWUNNEvaozpW5',
           'spotify:playlist:37i9dQZF1DX1MT1Ubz4wvO','spotify:playlist:37i9dQZF1DWZryfp6NSvtz',
           'spotify:playlist:37i9dQZF1DXcF6B6QPhFDv','spotify:playlist:37i9dQZF1DX78toxP7mOaJ',
           'spotify:playlist:37i9dQZF1DX1X7WV84927n','spotify:playlist:37i9dQZF1DWT2jS7NwYPVI',
           'spotify:playlist:37i9dQZF1DWWJOmJ7nRx0C','spotify:playlist:37i9dQZF1DX14rbJEM3cke',
           'spotify:playlist:37i9dQZF1DXd0ZFXhY0CRF','spotify:playlist:37i9dQZF1DX5a39zUmS7Hn',
           'spotify:playlist:37i9dQZF1DWVqJMsgEN0F4','spotify:playlist:37i9dQZF1DX82GYcclJ3Ug',]

urn='spotify:artist:6JkVYbxrHRB5hDD9tJmnag'
artist = sp.artist(urn)
print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JkVYbxrHRB5hDD9tJmnag'}, 'followers': {'href': None, 'total': 42}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag', 'id': '6JkVYbxrHRB5hDD9tJmnag', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebf0ed76baf430bac979fae246', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174f0ed76baf430bac979fae246', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178f0ed76baf430bac979fae246', 'height': 160, 'width': 160}], 'name': 'Praga', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:6JkVYbxrHRB5hDD9tJmnag'}

# %%
pl = sp.playlist_items("spotify:playlist:37i9dQZF1DX78toxP7mOaJ")
pl.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
pl['items'][0]['track']['album']['uri']
# Out:
# 'spotify:album:12tUJwwZFqQofxHxvlPEsA'

# %%
playlist_tracks = {'artist':[],'track':[],'album':[]}
for y in playlists:
    pl = sp.playlist_items(y)
    for x in pl['items']:
        playlist_tracks['track'].append(x['track']['uri'])
        playlist_tracks['artist'].append(x['track']['artists'][0]['uri']) ## 0 indica el artista principal
        playlist_tracks['album'].append(x['track']['album']['uri'])
        # print(x['artists'])
        # print(x['uri'])
print(len(playlist_tracks['track']))
# Out:
# 1187

# %%
df_tracks = pd.DataFrame(playlist_tracks)

# %%
print(df_tracks['artist'].nunique())
print(df_tracks['track'].nunique())
print(df_tracks['album'].nunique())
# Out:
# 748
# 975
# 937

# %% [markdown]
# ### Detalles de los tracks

# %%
tracks_list = df_tracks['track']
track = df_tracks['track'][0]
track
# Out:
# 'spotify:track:7fnlGpqyZ8KPATE5HXHrke'

# %%
### Features
track_features = {'track_id':[],'track_uri': [],'danceability':[],'energy':[], 'key':[],
                  'loudness':[],'mode':[],'acousticness':[],'instrumentalness':[],'liveness':[],'valence':[],'tempo':[],
                  'duration_ms':[],'time_signature':[]}
# trt = sp.track(track)
tr = sp.audio_features(track)
tr
# Out:
# [{'danceability': 0.554,
#   'energy': 0.784,
#   'key': 6,
#   'loudness': -7.591,
#   'mode': 1,
#   'speechiness': 0.0696,
#   'acousticness': 0.199,
#   'instrumentalness': 1.24e-05,
#   'liveness': 0.084,
#   'valence': 0.689,
#   'tempo': 167.386,
#   'type': 'audio_features',
#   'id': '5aWREznXDTWJ046mUoT162',
#   'uri': 'spotify:track:5aWREznXDTWJ046mUoT162',
#   'track_href': 'https://api.spotify.com/v1/tracks/5aWREznXDTWJ046mUoT162',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5aWREznXDTWJ046mUoT162',
#   'duration_ms': 239259,
#   'time_signature': 4}]

# %%
for i,track in enumerate(tracks_list):
    print("Elemento", i)
    tr = sp.audio_features(track)
    track_features['track_id'].append(tr[0]['id'])
    track_features['track_uri'].append(tr[0]['uri'])
    track_features['danceability'].append(tr[0]['danceability'])
    track_features['energy'].append(tr[0]['energy'])
    track_features['key'].append(tr[0]['key'])
    track_features['loudness'].append(tr[0]['loudness'])
    track_features['mode'].append(tr[0]['mode'])
    track_features['acousticness'].append(tr[0]['acousticness'])
    track_features['instrumentalness'].append(tr[0]['instrumentalness'])
    track_features['liveness'].append(tr[0]['liveness'])
    track_features['valence'].append(tr[0]['valence'])
    track_features['tempo'].append(tr[0]['tempo'])
    track_features['duration_ms'].append(tr[0]['duration_ms'])
    track_features['time_signature'].append(tr[0]['time_signature'])
print(track_features)
# Out:
# Elemento 0
# Elemento 1
# Elemento 2
# Elemento 3
# Elemento 4
# Elemento 5
# Elemento 6
# Elemento 7
# Elemento 8
# Elemento 9
# Elemento 10
# Elemento 11
# Elemento 12
# Elemento 13
# Elemento 14
# Elemento 15
# Elemento 16
# Elemento 17
# Elemento 18
# Elemento 19
# Elemento 20
# Elemento 21
# Elemento 22
# Elemento 23
# Elemento 24
# Elemento 25
# Elemento 26
# Elemento 27
# Elemento 28
# Elemento 29
# Elemento 30
# Elemento 31
# Elemento 32
# Elemento 33
# Elemento 34
# Elemento 35
# Elemento 36
# Elemento 37
# Elemento 38
# Elemento 39
# Elemento 40
# Elemento 41
# Elemento 42
# Elemento 43
# Elemento 44
# Elemento 45
# Elemento 46
# Elemento 47
# Elemento 48
# Elemento 49
# Elemento 50
# Elemento 51
# Elemento 52
# Elemento 53
# Elemento 54
# Elemento 55
# Elemento 56
# Elemento 57
# Elemento 58
# Elemento 59
# Elemento 60
# Elemento 61
# Elemento 62
# Elemento 63
# Elemento 64
# Elemento 65
# Elemento 66
# Elemento 67
# Elemento 68
# Elemento 69
# Elemento 70
# Elemento 71
# ...

# %%
df_features = pd.DataFrame(track_features)
df_features.to_csv('track_features.csv')

# %%
tr = sp.track(track)

# %%
### Info de tracks
tracks_dict = {'track_id':[],'track_uri':[],'track_name':[],
               'artist_uri':[],'artist_name':[],'track_popularity':[]}
tr['popularity']
# Out:
# 43

# %%
for i,track in enumerate(tracks_list):
    print("Elemento", i)
    tr = sp.track(track)
    tracks_dict['track_id'].append(tr['id'])
    tracks_dict['track_uri'].append(tr['uri'])
    tracks_dict['track_name'].append(tr['name'])
    tracks_dict['artist_uri'].append(tr['artists'][0]['uri'])
    tracks_dict['artist_name'].append(tr['artists'][0]['name'])
    tracks_dict['track_popularity'].append(tr['popularity'])
# Out:
# Elemento 0
# Elemento 1
# Elemento 2
# Elemento 3
# Elemento 4
# Elemento 5
# Elemento 6
# Elemento 7
# Elemento 8
# Elemento 9
# Elemento 10
# Elemento 11
# Elemento 12
# Elemento 13
# Elemento 14
# Elemento 15
# Elemento 16
# Elemento 17
# Elemento 18
# Elemento 19
# Elemento 20
# Elemento 21
# Elemento 22
# Elemento 23
# Elemento 24
# Elemento 25
# Elemento 26
# Elemento 27
# Elemento 28
# Elemento 29
# Elemento 30
# Elemento 31
# Elemento 32
# Elemento 33
# Elemento 34
# Elemento 35
# Elemento 36
# Elemento 37
# Elemento 38
# Elemento 39
# Elemento 40
# Elemento 41
# Elemento 42
# Elemento 43
# Elemento 44
# Elemento 45
# Elemento 46
# Elemento 47
# Elemento 48
# Elemento 49
# Elemento 50
# Elemento 51
# Elemento 52
# Elemento 53
# Elemento 54
# Elemento 55
# Elemento 56
# Elemento 57
# Elemento 58
# Elemento 59
# Elemento 60
# Elemento 61
# Elemento 62
# Elemento 63
# Elemento 64
# Elemento 65
# Elemento 66
# Elemento 67
# Elemento 68
# Elemento 69
# Elemento 70
# Elemento 71
# ...

# %%
print(len(tracks_dict['track_id']))
print(len(tracks_dict['track_uri']))
print(len(tracks_dict['track_name']))
print(len(tracks_dict['artist_uri']))
print(len(tracks_dict['artist_name']))
print(len(tracks_dict['track_popularity']))
# Out:
# 748
# 748
# 748
# 748
# 748
# 748

# %%
df_tracks = pd.DataFrame(tracks_dict)
df_tracks.to_csv('tracks.csv')

# %%
df_tracks.head()
df_features.head()
# Out:
#                  track_id                             track_uri  danceability  \
# 0  7fnlGpqyZ8KPATE5HXHrke  spotify:track:7fnlGpqyZ8KPATE5HXHrke         0.560
# 1  7LWvckYxoIoPb1QW6OnrEb  spotify:track:7LWvckYxoIoPb1QW6OnrEb         0.618
# 2  5NvqDMHAL38UTfNQFizEWm  spotify:track:5NvqDMHAL38UTfNQFizEWm         0.472
# 3  1pAYBMrUtPnCBexIsA7yag  spotify:track:1pAYBMrUtPnCBexIsA7yag         0.584
# 4  0vF9TaEJHO0Zm1ejF7AGC0  spotify:track:0vF9TaEJHO0Zm1ejF7AGC0         0.498
#
#    energy  key  loudness  mode  acousticness  instrumentalness  liveness  \
# 0   0.877    6    -4.534     1       0.01170          0.022100     0.328
# 1   0.737    4    -6.705     1       0.22500          0.000002     0.436
# 2   0.983   11    -5.469     1       0.00596          0.000679     0.139
# 3   0.645    3    -6.959     0       0.02810          0.321000     0.102
# 4   0.720    0    -7.812     1       0.09580          0.000025     0.243
#
#    valence    tempo  duration_ms  time_signature
# ...

# %%
df = pd.merge(df_tracks,df_features,on=['track_id','track_uri'])
df_sel = df.select_dtypes(include=['int','float'])

# %%
df_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_popularity  748 non-null    int64
#  1   danceability      748 non-null    float64
#  2   energy            748 non-null    float64
#  3   key               748 non-null    int64
#  4   loudness          748 non-null    float64
#  5   mode              748 non-null    int64
#  6   acousticness      748 non-null    float64
#  7   instrumentalness  748 non-null    float64
#  8   liveness          748 non-null    float64
#  9   valence           748 non-null    float64
#  10  tempo             748 non-null    float64
#  11  duration_ms       748 non-null    int64
#  12  time_signature    748 non-null    int64
# dtypes: float64(8), int64(5)
# memory usage: 76.1 KB

# %%
sns.heatmap(df_sel.corr().round(2), vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Conseguir las canciones desde los álbumes de los artistas

# %%
df_tracks.drop_duplicates(subset='artist',inplace=True)
artist_list = df_tracks['artist'].tolist()
artist_list
# Out:
# ['spotify:artist:1PpnPBZxWGm65wR6oS5Phy',
#  'spotify:artist:2f1pksYZS7c56itOgksEeE',
#  'spotify:artist:5Ed1kJRHN0Uj0BhGbRNutV',
#  'spotify:artist:2zfICaZaVlooSb1GFh6ZiP',
#  'spotify:artist:1jRwxa8eTgXDOhOlbRFFFy',
#  'spotify:artist:2nQcWlLWvXPTX34Ysqr2A2',
#  'spotify:artist:2BVE7Pqd8kxv9xEsuvoJoE',
#  'spotify:artist:5vnfKgHNYLnKeuFA6c2jJO',
#  'spotify:artist:34SgyDEDqVlahIQRDttgCn',
#  'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH',
#  'spotify:artist:1DiDa1DfTjldKJQeonyP33',
#  'spotify:artist:0mk9dVJMJF4fanFzeZo6K1',
#  'spotify:artist:5Vv5llyiK1nlME2UNDzPBB',
#  'spotify:artist:5IFjdKpLNCRPCRxdeXlFY9',
#  'spotify:artist:5bZw7KsPssYA9vjHvHgFVu',
#  'spotify:artist:4o7LzHKShbYcK8fAV1hjrg',
#  'spotify:artist:7raVfIwIqNjj5OGBbBQNDR',
#  'spotify:artist:3aqVNqgYvDz8VF5n6nJBDD',
#  'spotify:artist:5XHVcSAgMdrDfxw4WwsZB0',
#  'spotify:artist:5ahvDss0AH60cd2AWqoU1r',
#  'spotify:artist:2FN1YrHU65dhPZKl3GD7Vd',
#  'spotify:artist:15o4xwiKZWJ6jOFp9LeP24',
# ...

# %%
test_artist = playlist_tracks['artist'][0]
ar = sp.artist(test_artist)
arl = sp.artist_albums(test_artist, include_groups='album',limit=5)
arl['items'][0]
# Out:
# {'album_type': 'album',
#  'total_tracks': 12,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
# ...

# %%
albums = {'album':[],'album_name':[],'album_artist':[],'album_popularity':[]}
for artist in artist_list:
    album_item = sp.artist_albums(artist, include_groups='album',limit=5)['items']
    if len(album_item) > 0:
        print(album_item[0]['name'])
# Out:
# Si molesto, os vais
# Comida Rápida
# Futuro Inmediato
# Maquinaria
# Elige Tu Propia Aventura
# Desde Flores y Entrañas
# Mi motor en movimiento
# COWBOYS DE LA A3
# SUERTE, CHICA
# Me están apuntando con un arma
# Como Ladrones Sorprendidos
# Vacaciones Permanentes
# WOAH!
# Alcalá Norte
# Tú y Cuántos Más
# Puntos de Vista
# La Palmera (En Directo)
# Repion
# Cora Yako
# Amor Líquido
# Gran Hostal
# ¡AHORA!
# Corizonas III
# VIVA HINDS
# La Reconciliación
# Un puño amable
# Los Bancos Del Reina.
# Nº1
# Entre Amores y Errores
# Dos
# Duelo de ronda
# Todavía no
# Actitud ganadora
# AFDTRQHOT
# Bohemian Rhapsody 2
# Plaza patines
# La juventud
# Me Doy Cuenta
# Un Año De Cambios
# Nadie Patín
# DICTADURA TRAVESTI
# Que adoren tus huesos
# DIRECTOS AL INFIERNO
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[134], line 3
# ...

# %%
playlist_tracks['artist']
# Out:
# ['spotify:artist:1PpnPBZxWGm65wR6oS5Phy',
#  'spotify:artist:2f1pksYZS7c56itOgksEeE',
#  'spotify:artist:5Ed1kJRHN0Uj0BhGbRNutV',
#  'spotify:artist:2zfICaZaVlooSb1GFh6ZiP',
#  'spotify:artist:1jRwxa8eTgXDOhOlbRFFFy',
#  'spotify:artist:2nQcWlLWvXPTX34Ysqr2A2',
#  'spotify:artist:2BVE7Pqd8kxv9xEsuvoJoE',
#  'spotify:artist:5vnfKgHNYLnKeuFA6c2jJO',
#  'spotify:artist:34SgyDEDqVlahIQRDttgCn',
#  'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH',
#  'spotify:artist:2BVE7Pqd8kxv9xEsuvoJoE',
#  'spotify:artist:1DiDa1DfTjldKJQeonyP33',
#  'spotify:artist:1PpnPBZxWGm65wR6oS5Phy',
#  'spotify:artist:0mk9dVJMJF4fanFzeZo6K1',
#  'spotify:artist:5Vv5llyiK1nlME2UNDzPBB',
#  'spotify:artist:5Ed1kJRHN0Uj0BhGbRNutV',
#  'spotify:artist:5IFjdKpLNCRPCRxdeXlFY9',
#  'spotify:artist:1PpnPBZxWGm65wR6oS5Phy',
#  'spotify:artist:5vnfKgHNYLnKeuFA6c2jJO',
#  'spotify:artist:2f1pksYZS7c56itOgksEeE',
#  'spotify:artist:5bZw7KsPssYA9vjHvHgFVu',
#  'spotify:artist:4o7LzHKShbYcK8fAV1hjrg',
# ...

# %%
data = sp.artist_top_tracks(urn,country='ES')
for x in data['tracks']:
    print(x['name'])
    print(x['artists'])
    print(x['uri'])
# Out:
# La Luz
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JkVYbxrHRB5hDD9tJmnag'}, 'href': 'https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag', 'id': '6JkVYbxrHRB5hDD9tJmnag', 'name': 'Praga', 'type': 'artist', 'uri': 'spotify:artist:6JkVYbxrHRB5hDD9tJmnag'}]
# spotify:track:6nwyrW2BlWSw8GazRJkTkH
# Falso Final
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JkVYbxrHRB5hDD9tJmnag'}, 'href': 'https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag', 'id': '6JkVYbxrHRB5hDD9tJmnag', 'name': 'Praga', 'type': 'artist', 'uri': 'spotify:artist:6JkVYbxrHRB5hDD9tJmnag'}]
# spotify:track:3JOUWuxt3QjRGintxr4MIa
# Restaurantes Chinos
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JkVYbxrHRB5hDD9tJmnag'}, 'href': 'https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag', 'id': '6JkVYbxrHRB5hDD9tJmnag', 'name': 'Praga', 'type': 'artist', 'uri': 'spotify:artist:6JkVYbxrHRB5hDD9tJmnag'}]
# spotify:track:3ngLpZZOyqLMBHGyTNC6Oc
# ...

# %%
data
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JkVYbxrHRB5hDD9tJmnag'},
#       'href': 'https://api.spotify.com/v1/artists/6JkVYbxrHRB5hDD9tJmnag',
#       'id': '6JkVYbxrHRB5hDD9tJmnag',
#       'name': 'Praga',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JkVYbxrHRB5hDD9tJmnag'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
# ...

# %%
track = 'spotify:track:3ngLpZZOyqLMBHGyTNC6Oc'
sp.audio_analysis(track)
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1694370174,
#   'analysis_time': 7.85522,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4161024,
#   'duration': 188.70857,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 2.26975,
#   'start_of_fade_out': 181.05179,
#   'loudness': -9.668,
#   'tempo': 90.058,
#   'tempo_confidence': 0.352,
#   'time_signature': 4,
#   'time_signature_confidence': 0.967,
#   'key': 7,
#   'key_confidence': 0.395,
#   'mode': 1,
#   'mode_confidence': 0.498,
# ...

# %%
datos_bicis = pd.read_json('data/202106_movements.json', lines=True, encoding='latin-1', nrows=10000)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4096 entries, bass_synthetic_068-049-025 to bass_synthetic_009-058-025
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   qualities              4096 non-null   object
#  1   pitch                  4096 non-null   object
#  2   note                   4096 non-null   object
#  3   instrument_source_str  4096 non-null   object
#  4   velocity               4096 non-null   object
#  5   instrument_str         4096 non-null   object
#  6   instrument             4096 non-null   object
#  7   sample_rate            4096 non-null   object
#  8   qualities_str          4096 non-null   object
#  9   instrument_source      4096 non-null   object
#  10  note_str               4096 non-null   object
#  11  instrument_family      4096 non-null   object
#  12  instrument_family_str  4096 non-null   object
# dtypes: object(13)
# memory usage: 577.0+ KB

# %% [markdown]
# ## Pruebas con librosa

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# 1. Get the file path to an included audio example

filename = librosa.example('nutcracker')

# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`

y, sr = librosa.load('data/test/adios.mp3')


# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)


# print('Estimated tempo: {:.2f} beats per minute'.format(tempo))


# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
beat_times
# Out:
# array([  0.65015873,   1.36997732,   2.08979592,   2.71673469,
#          3.4829932 ,   4.22603175,   4.94585034,   5.61922902,
#          6.38548753,   7.10530612,   7.84834467,   8.56816327,
#          9.19510204,  10.00780045,  10.72761905,  11.44743764,
#         12.19047619,  12.88707483,  13.60689342,  14.32671202,
#         15.02331066,  15.74312925,  16.46294785,  17.18276644,
#         17.92580499,  18.64562358,  19.36544218,  20.08526077,
#         20.80507937,  21.52489796,  22.24471655,  22.96453515,
#         23.68435374,  24.38095238,  25.05433107,  25.75092971,
#         26.49396825,  27.26022676,  27.98004535,  28.69986395,
#         29.41968254,  30.16272109,  30.85931973,  31.57913832,
#         32.32217687,  33.04199546,  33.7385941 ,  34.4584127 ,
#         35.17823129,  35.9444898 ,  36.66430839,  37.38412698,
#         38.10394558,  38.80054422,  39.52036281,  40.24018141,
#         40.96      ,  41.65659864,  42.37641723,  43.09623583,
# ...

# %%
filename = librosa.ex('fishin')

y, sr = librosa.load(filename, duration=5, offset=35)

# Generate a Mel spectrogram:

M = librosa.feature.melspectrogram(y=y)

# Of course, you can still override the new default manually, e.g.:

M_highres = librosa.feature.melspectrogram(y=y, hop_length=512)


# And plot the results
fig, ax = plt.subplots(nrows=3, sharex=True, sharey=True)

librosa.display.specshow(librosa.power_to_db(M, ref=np.max),
                         y_axis='mel', x_axis='time', ax=ax[0])

ax[0].set(title='44100/1024/4096')
ax[0].label_outer()

librosa.display.specshow(librosa.power_to_db(M_highres, ref=np.max),
                         hop_length=512,
                         y_axis='mel', x_axis='time', ax=ax[1])
ax[1].set(title='44100/512/4096')
ax[1].label_outer()

# We can repeat the whole process with different defaults, just by
# updating the parameter entries
librosa['sr'] = 11025

y2, sr2 = librosa.load(filename, duration=5, offset=35)
M2 = librosa.feature.melspectrogram(y=y2, sr=sr2)

librosa.display.specshow(librosa.power_to_db(M2, ref=np.max),
                         y_axis='mel', x_axis='time', ax=ax[2])

ax[2].set(title='11025/1024/4096')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 31
#      27 ax[1].label_outer()
#      29 # We can repeat the whole process with different defaults, just by
#      30 # updating the parameter entries
# ---> 31 librosa['sr'] = 11025
#      33 y2, sr2 = librosa.load(filename, duration=5, offset=35)
#      34 M2 = librosa.feature.melspectrogram(y=y2, sr=sr2)
#
# TypeError: 'module' object does not support item assignment

# %%
y, sr = librosa.load('data/test/chinos.wav')
tempo = librosa.feature.tempo(y=y,sr=sr)
tempo
# Out:
# array([89.10290948])

# %% [markdown]
# ## Pruebas OECD

# %% [markdown]
# ### Coastal

# %%
coastal = pd.read_csv('./data/oecd/raw/coastal_flood.csv')
coastal.head()
# Out:
#   STRUCTURE                                     STRUCTURE_ID  \
# 0  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 1  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 2  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 3  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 4  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
#
#                        STRUCTURE_NAME ACTION REF_AREA  \
# 0  Coastal flooding - Cities and FUAs      I   MEX85F
# 1  Coastal flooding - Cities and FUAs      I   MEX85F
# 2  Coastal flooding - Cities and FUAs      I   BG018C
# 3  Coastal flooding - Cities and FUAs      I   BG018C
# 4  Coastal flooding - Cities and FUAs      I   ES006C
#
#                Reference area FREQ Frequency of observation       MEASURE  \
# 0  Iguala de la Independencia    A                   Annual    CF_POP_EXP
# 1  Iguala de la Independencia    A                   Annual    CF_POP_EXP
# ...

# %%
coastal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244804 entries, 0 to 244803
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   STRUCTURE                 244804 non-null  object
#  1   STRUCTURE_ID              244804 non-null  object
#  2   STRUCTURE_NAME            244804 non-null  object
#  3   ACTION                    244804 non-null  object
#  4   REF_AREA                  244804 non-null  object
#  5   Reference area            244804 non-null  object
#  6   FREQ                      244804 non-null  object
#  7   Frequency of observation  244804 non-null  object
#  8   MEASURE                   244804 non-null  object
#  9   Measure                   244804 non-null  object
#  10  UNIT_MEASURE              244804 non-null  object
#  11  Unit of measure           244804 non-null  object
#  12  RET_PERIOD                244804 non-null  object
# ...

# %%
coastal = coastal.drop(coastal[coastal['RET_PERIOD'].isin(['Y_10', 'Y_50', 'Y_100'])].index)
coastal = coastal.drop(coastal[coastal['MEASURE'] == 'CF_BUILT_EXP'].index)

# %%
coastal['MEASURE'].value_counts()
# Out:
# MEASURE
# CF_POP_EXP    5322
# Name: count, dtype: int64

# %%
coastal['id'] = coastal['REF_AREA'].astype(str) + coastal['TIME_PERIOD'].astype(str)
coastal['RET_PERIOD'].value_counts()
# Out:
# RET_PERIOD
# Y_10     61201
# Y_50     61201
# Y_25     61201
# Y_100    61201
# Name: count, dtype: int64

# %%
coastal.head()
# Out:
#    STRUCTURE                                     STRUCTURE_ID  \
# 48  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 49  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 54  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 55  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
# 77  DATAFLOW  OECD.CFE.EDS:DSD_FUA_CLIM@DF_COASTAL_FLOOD(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 48  Coastal flooding - Cities and FUAs      I   DE001F         Berlin    A
# 49  Coastal flooding - Cities and FUAs      I   DE001F         Berlin    A
# 54  Coastal flooding - Cities and FUAs      I   NL026C      Hilversum    A
# 55  Coastal flooding - Cities and FUAs      I   NL026C      Hilversum    A
# 77  Coastal flooding - Cities and FUAs      I   CL013F      Melipilla    A
#
#    Frequency of observation     MEASURE  \
# 48                   Annual  CF_POP_EXP
# 49                   Annual  CF_POP_EXP
# ...

# %%
coastal_extract = coastal
coastal_extract = coastal_extract[['id','REF_AREA','TIME_PERIOD','OBS_VALUE','TERRITORIAL_LEVEL']]
coastal_extract.rename(columns={'OBS_VALUE':'COASTAL_FLOOD_VALUE'},inplace=True)
coastal_extract.to_csv('./data/oecd/processed/coastal.csv',index=False)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_14420\4139328067.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coastal_extract.rename(columns={'OBS_VALUE':'COASTAL_FLOOD_VALUE'},inplace=True)

# %% [markdown]
# ### Urban Heat

# %%
urban = pd.read_csv('./data/oecd/raw/urban_heat.csv')
urban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55965 entries, 0 to 55964
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   STRUCTURE                   55965 non-null  object
#  1   STRUCTURE_ID                55965 non-null  object
#  2   STRUCTURE_NAME              55965 non-null  object
#  3   ACTION                      55965 non-null  object
#  4   REF_AREA                    55965 non-null  object
#  5   Reference area              55965 non-null  object
#  6   FREQ                        55965 non-null  object
#  7   Frequency of observation    55965 non-null  object
#  8   MEASURE                     55965 non-null  object
#  9   Measure                     55965 non-null  object
#  10  UNIT_MEASURE                55965 non-null  object
#  11  Unit of measure             55965 non-null  object
#  12  PM_CONCENTRATION            55965 non-null  object
# ...

# %%
urban['id'] = urban['REF_AREA'].astype(str) + urban['TIME_PERIOD'].astype(str)
urban = urban.drop(urban[urban['TIME_SEASON'].isin(['DAY_SUMMER','NIGHT_T','NIGHT_SUMMER'])].index)
urban['id'].value_counts()

# %%
urban_extract = urban[['id','REF_AREA','TIME_PERIOD','OBS_VALUE','TERRITORIAL_LEVEL']]
urban_extract.rename(columns={'OBS_VALUE':'URBAN_HEAT_VALUE'},inplace=True)
urban_extract.to_csv('./data/oecd/processed/urban.csv',index=False)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_14420\370418988.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urban_extract.rename(columns={'OBS_VALUE':'URBAN_HEAT_VALUE'},inplace=True)

# %% [markdown]
# ### Green Areas

# %%
### Prio baja, sólo desde el 2020

# %% [markdown]
# ### Heat stress

# %%
heat = pd.read_csv('./data/oecd/raw/heat_stress.csv')
heat['id'] = heat['REF_AREA'].astype(str) + heat['TIME_PERIOD'].astype(str)
heat.head(2).T
# Out:
#                                                                       0  \
# STRUCTURE                                                      DATAFLOW
# STRUCTURE_ID              OECD.CFE.EDS:DSD_FUA_CLIM@DF_HEAT_STRESS(1.0)
# STRUCTURE_NAME                            Heat stress - Cities and FUAs
# ACTION                                                                I
# REF_AREA                                                         ES072C
# Reference area                                                     León
# FREQ                                                                  A
# Frequency of observation                                         Annual
# MEASURE                                                    UTCI_POP_EXP
# Measure                         Mean population exposure to heat stress
# UNIT_MEASURE                                                        D_Y
# Unit of measure                                           Days per year
# ...

# %%
heat_extract = heat[['id','REF_AREA','TIME_PERIOD','OBS_VALUE','TERRITORIAL_LEVEL']]
heat_extract.rename(columns={'OBS_VALUE':'HEAT_VALUE'},inplace=True)
heat_extract.to_csv('./data/oecd/processed/heat.csv',index=False)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_14420\1650938290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heat_extract.rename(columns={'OBS_VALUE':'HEAT_VALUE'},inplace=True)

# %% [markdown]
# ### Pollution

# %%
pollution = pd.read_csv('./data/oecd/raw/pollution.csv')
pollution['id'] = pollution['REF_AREA'].astype(str) + pollution['TIME_PERIOD'].astype(str)
pollution_extract = pollution[['id','REF_AREA','TIME_PERIOD','OBS_VALUE','TERRITORIAL_LEVEL']]
pollution_extract.rename(columns={'OBS_VALUE':'POLLUTION_VALUE'},inplace=True)
pollution_extract.to_csv('./data/oecd/processed/pollution.csv',index=False)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_14420\1341528007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pollution_extract.rename(columns={'OBS_VALUE':'POLLUTION_VALUE'},inplace=True)

# %%
pollution['id'].value_counts()
# Out:
# id
# FR005C2020    1
# AUS10C1990    1
# AUS10C1995    1
# FR005C2004    1
# FR005C2003    1
#              ..
# AUS10C2005    1
# AUS10C2004    1
# AUS10C2003    1
# AUS10C2002    1
# AUS10C2001    1
# Name: count, Length: 61203, dtype: int64

# %% [markdown]
# ### River Flood

# %%
river = pd.read_csv('./data/oecd/raw/river_flood.csv')
river['id'] = river['REF_AREA'].astype(str) + river['TIME_PERIOD'].astype(str)
river_extract = river[['id','REF_AREA','TIME_PERIOD','OBS_VALUE','TERRITORIAL_LEVEL']]
river_extract.rename(columns={'OBS_VALUE':'RIVER_FLOOD_VALUE'},inplace=True)
river_extract.to_csv('./data/oecd/processed/river.csv',index=False)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_14420\3645856639.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   river_extract.rename(columns={'OBS_VALUE':'RIVER_FLOOD_VALUE'},inplace=True)

# %% [markdown]
# ### First Merge

# %%
coastal = pd.read_csv('./data/oecd/processed/coastal.csv')
heat = pd.read_csv('./data/oecd/processed/heat.csv')
pollution = pd.read_csv('./data/oecd/processed/pollution.csv')
river = pd.read_csv('./data/oecd/processed/river.csv')
urban = pd.read_csv('./data/oecd/processed/urban.csv')

# %%
df = pd.merge(urban,river[['id','RIVER_FLOOD_VALUE']], on='id',how='left')
df = pd.merge(df,coastal[['id','COASTAL_FLOOD_VALUE']], on='id',how='left')
df = pd.merge(df,heat[['id','HEAT_VALUE']], on='id',how='left')
df = pd.merge(df,pollution[['id','POLLUTION_VALUE']], on='id',how='left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13992 entries, 0 to 13991
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   13992 non-null  object
#  1   REF_AREA             13992 non-null  object
#  2   TIME_PERIOD          13992 non-null  int64
#  3   URBAN_HEAT_VALUE     13992 non-null  float64
#  4   TERRITORIAL_LEVEL    13992 non-null  object
#  5   RIVER_FLOOD_VALUE    1272 non-null   float64
#  6   COASTAL_FLOOD_VALUE  1272 non-null   float64
#  7   HEAT_VALUE           13992 non-null  int64
#  8   POLLUTION_VALUE      12720 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 983.9+ KB

# %%
df_nans = df.dropna(axis=0,how='any')
df_nans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1272 entries, 4 to 13985
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1272 non-null   object
#  1   REF_AREA             1272 non-null   object
#  2   TIME_PERIOD          1272 non-null   int64
#  3   URBAN_HEAT_VALUE     1272 non-null   float64
#  4   TERRITORIAL_LEVEL    1272 non-null   object
#  5   RIVER_FLOOD_VALUE    1272 non-null   float64
#  6   COASTAL_FLOOD_VALUE  1272 non-null   float64
#  7   HEAT_VALUE           1272 non-null   int64
#  8   POLLUTION_VALUE      1272 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 99.4+ KB

# %%
df_nans = df_nans[['POLLUTION_VALUE','HEAT_VALUE','COASTAL_FLOOD_VALUE','RIVER_FLOOD_VALUE','URBAN_HEAT_VALUE']]
sns.heatmap(df_nans.corr(), vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >
